# %%
import pandas as pd

# %%
df = pd.read_csv('nan.csv', sep = ';')

# %%
df.head()
# Out:
#                                              premise  \
# 0  Not all people have had the opportunities you ...
# 1  Not all people have had the opportunities you ...
# 2  Not all people have had the opportunities you ...
# 3  Not all people have had the opportunities you ...
# 4  Not all people have had the opportunities you ...
#
#                                           hypothesis          label  \
# 0  Some people have not had the opportunities you...     entailment
# 1  Some people have had the opportunities you hav...     entailment
# 2  Every person has had the opportunities you hav...  contradiction
# 3  Not every person has had the opportunities you...     entailment
# 4  All people have not had the opportunities you ...  contradiction
#
#    Unnamed: 3  Unnamed: 4  P-Verbal  P-Non-verbal  P-Analytic  P-Synthetic  \
# 0         NaN         NaN         0             1           1            0
# 1         NaN         NaN         0             1           1            0
# ...

# %%
df.columns
# Out:
# Index(['premise', 'hypothesis', 'label', 'Unnamed: 3', 'Unnamed: 4',
#        'P-Verbal', 'P-Non-verbal', 'P-Analytic', 'P-Synthetic', 'P-Clausal',
#        'P-Sub-clausal', 'P-Ordinary', 'P-Meta-linguistic', 'Unnamed: 13',
#        'H-Verbal', 'H-Non-verbal', 'H-Analytic', 'H-Synthetic', 'H-Clausal',
#        'H-Sub-clausal', 'H-Ordinary', 'H-Meta-linguistic', 'Unnamed: 22',
#        'Construction', 'Construction Subtype', 'Indefinite quantifier change',
#        'Negator addition or deletion', 'Negator position change',
#        'Clause or sub-clause deletion', 'Negator token change',
#        'Comparative quantifier change', 'Focus particle change',
#        'lexical change', 'numerical quantifier change', 'syntactical changes',
#        'quantification'],
#       dtype='object')

# %%
df = df.drop(columns=['Unnamed: 3', 'Unnamed: 4'])

# %%
df = df.rename(columns={'lexical change': 'Lexical change', 'numerical quantifier change': 'Numerical quantifier change', 'syntactical changes' :'Syntactical changes', 'quantification': 'Quantification'})

# %%
# Out:
#                                              premise  \
# 0  Not all people have had the opportunities you ...
# 1  Not all people have had the opportunities you ...
# 2  Not all people have had the opportunities you ...
# 3  Not all people have had the opportunities you ...
# 4  Not all people have had the opportunities you ...
#
#                                           hypothesis          label  P-Verbal  \
# 0  Some people have not had the opportunities you...     entailment         0
# 1  Some people have had the opportunities you hav...     entailment         0
# 2  Every person has had the opportunities you hav...  contradiction         0
# 3  Not every person has had the opportunities you...     entailment         0
# 4  All people have not had the opportunities you ...  contradiction         0
#
#    P-Non-verbal  P-Analytic  P-Synthetic  P-Clausal  P-Sub-clausal  \
# 0             1           1            0          0              1
# ...

# %%
df.to_csv('nan_clean.csv', index = False)
